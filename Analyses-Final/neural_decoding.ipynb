# %% [markdown]
# # Decoding analysis
#
#
# #### TODO:
# - remove 'Geen van Allen' trials. in what step though? need to also remove congruent st-zscores
# - fix splitting

# %%
import sys
sys.path.append('/home/c10370862/FEED_new/scripts/')
import encoding as enc
import numpy as np
import nibabel as nib
from nistats.first_level_model import FirstLevelModel
from nilearn.masking import apply_mask
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %% [markdown]
# ### Calculate Single trial zscores:

# %%
sub_labels = ['04','13']
task = 'expressive'
space = 'T1w'
filt = ['face']
conf_cols = ['cosine00','cosine01', 
             'trans_x','trans_y','trans_z',
             'rot_x','rot_y','rot_z','csf', 'white_matter']

# %%
st_zscores = []
models_events = []
AU_arrays = []
#loop over subjects and load files
for sub in sub_labels:
    imgs, events, conf, func_mask, json = enc.load_and_create_obj(sub, task, space,
                                                                  mask='func',
                                                                  skip_missing=True)
    
    #filter events and select confounds
    events = enc.filter_event_type(events,filt,keep=True)
    
    for idx, c in enumerate(conf):
        conf[idx] = c.loc[:, conf_cols]
    
    #fix trial_type
    for idx, e in enumerate(events):
        e = e[e.data_split == 'train']
        e['trial_id'] = e.trial_type
        trial_names = []
        for t in range(e.shape[0]):
            trial_names.append('trial ' + str(t))
        e.trial_type = trial_names
        events[idx] = e
    
    #initialize model and arguments
    n_runs = len(imgs)
    n_trials = len(trial_names)
    n_vox = int(np.sum(nib.load(func_mask).get_data()))
    AU_cols = [col for col in events[0].columns if 'AU' in col and col != 'N_AUs']
    
    AU_array_all = np.zeros((n_runs,n_trials,len(AU_cols)))
    z_array_all = np.zeros((n_runs,n_trials,n_vox))
    tr = json.RepetitionTime[0]
    model = FirstLevelModel(t_r=tr,
                            hrf_model='glover + derivative',
                            drift_model=None,
                            smoothing_fwhm=3,
                            mask = func_mask,
                            verbose=0,
                            n_jobs=10
                           )
    #fit single trials
    for run_idx, run in enumerate(imgs):
        print('fitting run %i out of %i' %(run_idx+1, len(imgs)))
        model.fit(run, events[run_idx], conf[run_idx])
        zscore = np.zeros((n_trials, n_vox))
        print('processing single trial z-scores')
        for trial_ind, trial in enumerate(trial_names):
            z = model.compute_contrast(trial, output_type = 'z_score')
            z = apply_mask(z, model.mask_img)
            z_array_all[run_idx, trial_ind,:] = z
        AU_array_all[run_idx,:,:] = events[run_idx].loc[:,AU_cols].values
    
    st_zscores.append(z_array_all)
    AU_arrays.append(AU_array_all)
    models_events.append(events)
# Out:
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-3_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-3_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-3_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-4_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-4_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-4_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-5_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-5_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-5_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-6_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-6_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-6_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-7_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-7_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-7_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-8_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-8_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face1/func/sub-04_ses-face1_task-expressive_run-8_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-1_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-1_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-1_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-2_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-2_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-2_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-3_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-3_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-3_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-4_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-4_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-4_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-5_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-5_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-5_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-6_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-6_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-6_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-7_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-7_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-7_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-8_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-8_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face2/func/sub-04_ses-face2_task-expressive_run-8_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-1_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-1_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-1_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-2_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-2_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-2_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-3_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-3_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-3_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-4_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-4_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-4_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-5_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-5_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-5_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-6_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-6_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-6_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-7_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-7_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-7_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-8_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-8_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-04/ses-face3/func/sub-04_ses-face3_task-expressive_run-8_desc-confounds_regressors.tsv')
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:41: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.
# /opt/conda/lib/python3.6/site-packages/nilearn/_utils/cache_mixin.py:232: DeprecationWarning: The 'cachedir' attribute has been deprecated in version 0.12 and will be removed in version 0.14.
# Use os.path.join(memory.location, 'joblib') attribute instead.
#   if (memory.cachedir is None and memory_level is not None
# fitting run 1 out of 22
# processing single trial z-scores
# fitting run 2 out of 22
# processing single trial z-scores
# fitting run 3 out of 22
# processing single trial z-scores
# fitting run 4 out of 22
# processing single trial z-scores
# fitting run 5 out of 22
# processing single trial z-scores
# fitting run 6 out of 22
# processing single trial z-scores
# fitting run 7 out of 22
# processing single trial z-scores
# fitting run 8 out of 22
# processing single trial z-scores
# fitting run 9 out of 22
# processing single trial z-scores
# fitting run 10 out of 22
# processing single trial z-scores
# fitting run 11 out of 22
# processing single trial z-scores
# fitting run 12 out of 22
# processing single trial z-scores
# fitting run 13 out of 22
# processing single trial z-scores
# fitting run 14 out of 22
# processing single trial z-scores
# fitting run 15 out of 22
# processing single trial z-scores
# fitting run 16 out of 22
# processing single trial z-scores
# fitting run 17 out of 22
# processing single trial z-scores
# fitting run 18 out of 22
# processing single trial z-scores
# fitting run 19 out of 22
# processing single trial z-scores
# fitting run 20 out of 22
# processing single trial z-scores
# fitting run 21 out of 22
# processing single trial z-scores
# fitting run 22 out of 22
# processing single trial z-scores
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-1_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-1_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-1_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-2_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-2_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-2_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-3_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-3_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-3_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-4_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-4_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-4_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-5_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-5_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-5_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-6_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-6_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-6_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-7_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-7_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-7_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-8_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-8_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face1/func/sub-13_ses-face1_task-expressive_run-8_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-1_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-1_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-1_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-2_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-2_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-2_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-3_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-3_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-3_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-4_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-4_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-4_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-5_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-5_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-5_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-6_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-6_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-6_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-7_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-7_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-7_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-8_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-8_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face2/func/sub-13_ses-face2_task-expressive_run-8_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-1_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-1_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-1_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-2_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-2_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-2_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-3_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-3_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-3_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-4_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-4_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-4_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-5_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-5_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-5_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-7_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-7_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-7_desc-confounds_regressors.tsv')
# ('loading files '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-8_space-T1w_desc-preproc_bold.nii.gz, '
#  '/srv/FEED/mri_data/bids/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-8_events.tsv, '
#  '/srv/FEED/mri_data/bids/derivatives/fmriprep/sub-13/ses-face3/func/sub-13_ses-face3_task-expressive_run-8_desc-confounds_regressors.tsv')
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:41: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.
# /opt/conda/lib/python3.6/site-packages/nilearn/_utils/cache_mixin.py:232: DeprecationWarning: The 'cachedir' attribute has been deprecated in version 0.12 and will be removed in version 0.14.
# Use os.path.join(memory.location, 'joblib') attribute instead.
#   if (memory.cachedir is None and memory_level is not None
# fitting run 1 out of 23
# processing single trial z-scores
# fitting run 2 out of 23
# processing single trial z-scores
# fitting run 3 out of 23
# processing single trial z-scores
# fitting run 4 out of 23
# processing single trial z-scores
# fitting run 5 out of 23
# processing single trial z-scores
# fitting run 6 out of 23
# processing single trial z-scores
# fitting run 7 out of 23
# processing single trial z-scores
# fitting run 8 out of 23
# processing single trial z-scores
# fitting run 9 out of 23
# processing single trial z-scores
# fitting run 10 out of 23
# processing single trial z-scores
# fitting run 11 out of 23
# processing single trial z-scores
# fitting run 12 out of 23
# processing single trial z-scores
# fitting run 13 out of 23
# processing single trial z-scores
# fitting run 14 out of 23
# processing single trial z-scores
# fitting run 15 out of 23
# processing single trial z-scores
# fitting run 16 out of 23
# processing single trial z-scores
# fitting run 17 out of 23
# processing single trial z-scores
# fitting run 18 out of 23
# processing single trial z-scores
# fitting run 19 out of 23
# processing single trial z-scores
# fitting run 20 out of 23
# processing single trial z-scores
# fitting run 21 out of 23
# processing single trial z-scores
# fitting run 22 out of 23
# processing single trial z-scores
# fitting run 23 out of 23
# processing single trial z-scores

# %% [markdown]
# ### Decoding

# %%
from glob import glob
import pandas as pd

def create_emo_df(sub, task):

    files = (glob('/srv/FEED/behav_data/sub-{}/*ses-*_task-{}*run*.tsv'.format(sub,task)))
    files.sort()
    #pprint('found the following files for sub-%s: %s' %(sub,[f for f in files]))
    dfs = []
    for i, file in enumerate(files):
        if 'ses-1_' not in file:
            if 'redo' not in file:
                print('skipping file %s' %(file))
                continue
        print('loading file %s' %(file))
        tmp_df = pd.read_csv(file, sep = '\t', index_col=0)
        tmp_df['new_index'] = tmp_df.index+len(tmp_df)*(i)
        tmp_df = tmp_df.set_index(tmp_df.new_index.values)
        dfs.append(tmp_df)
    df = pd.concat(dfs, sort = False)

    df = df.loc[df.rating_category.notna(),:]
    #df = df.loc[df.rating_category != 'Geen van allen']
    df = df.loc[df.data_split == 'train']
    emo_cols = ['rating_category', 'rating_intensity_norm', 'trial_type']
    emo_df = df[emo_cols]
    return emo_df

# %%
import behav

# %%
import decoding as dec
import behav

sub_labels = ['04','13']
task = 'expressive'
events_y = []
for sub_idx, sub in enumerate(sub_labels):
    emo_df = create_emo_df(sub, task)
    for event_idx, e in enumerate(models_events[sub_idx]):
        rating = []
        for trial_idx, trial in enumerate(e.trial_id):
            answer = emo_df.rating_category[emo_df.trial_type == trial]
            rating.append(answer.values[0])
        e['rating_category'] = rating
        models_events[sub_idx][event_idx] = e
    events_y.append(pd.concat(models_events[sub_idx]))
# Out:
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-1_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-1_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-1_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-1_task-expressive_run-4.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-1_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-2_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-3_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-4.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-4_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-1_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-2_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-3_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-4.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-4_redo.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-1_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-1_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-1_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-1_task-expressive_run-4.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-1_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-2_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-3_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-4.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-4_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-1_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-2_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-3_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-4.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-4_redo.tsv

# %%
counts = []
for sub_idx, sub in enumerate(sub_labels):
    emo_df =  create_emo_df(sub, task)
    counts.append(emo_df.rating_category.value_counts())
    #print(emo_df.rating_category.value_counts())
    #print(np.sum(emo_df.rating_category.value_counts().values))
print(counts)
np.std(np.vstack(counts), axis=0)
# Out:
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-1_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-1_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-1_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-1_task-expressive_run-4.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-1_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-2_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-3_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-4.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-2_task-expressive_run-4_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-1_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-2_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-3_redo.tsv
# skipping file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-4.tsv
# loading file /srv/FEED/behav_data/sub-04/sub-04_ses-3_task-expressive_run-4_redo.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-1_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-1_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-1_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-1_task-expressive_run-4.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-1_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-2_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-3_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-4.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-2_task-expressive_run-4_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-1.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-1_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-2.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-2_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-3.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-3_redo.tsv
# skipping file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-4.tsv
# loading file /srv/FEED/behav_data/sub-13/sub-13_ses-3_task-expressive_run-4_redo.tsv
# [Blij              159
# Walging           153
# Boos              127
# Verrassing         98
# Bang               85
# Verdrietig         66
# Geen van allen      8
# Name: rating_category, dtype: int64, Geen van allen    235
# Blij              133
# Boos               92
# Walging            67
# Verrassing         61
# Bang               60
# Verdrietig         48
# Name: rating_category, dtype: int64]
# array([38. , 10. , 17.5, 15.5, 12. ,  3. , 20. ])

# %%
from sklearn.model_selection import train_test_split

X_train_list = []
X_test_list = []
y_train_list = []
y_test_list = []

data = zip(st_zscores,events_y, sub_labels)
for st_z, events, sub in data:
    X = np.vstack(st_z)
    y = events.rating_category
    drop = []
    for idx, trial in enumerate(y):
        if trial == 'Geen van allen':
            drop.append(idx)
    X = np.delete(X, drop, axis=0)
    y = y[y != 'Geen van allen']
    X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = 0.2, stratify = y)
    X_train_list.append(X_train)
    X_test_list.append(X_test)
    y_train_list.append(y_train)
    y_test_list.append(y_test)
    n_trials_test = X_test.shape[0]
    print('test size for sub-%s: %i' %(sub, n_trials_test))
n_test_avg = np.mean([X_test_list[0].shape[0],X_test_list[1].shape[0]])
print('average test size: %.1f'%(n_test_avg))
# Out:
# test size for sub-04: 127
# test size for sub-13: 89
# average test size: 108.0

# %%
from pathlib import Path
import os
import os.path as op
file_path = op.join(str(Path('.').absolute().parent),'files/dec_files')
if not op.exists(file_path):
    os.makedirs(file_path)
for i, sub in enumerate(sub_labels):
    np.savetxt(op.join(file_path, 'neural_funcSTS_X_train_sub-{}'.format(sub)),X_train_list[i], delimiter='\t')
    np.savetxt(op.join(file_path, 'neural_funcSTS_X_test_sub-{}'.format(sub)),X_test_list[i], delimiter='\t')
    y_train_list[i].to_csv(op.join(file_path, 'neural_funcSTS_y_train_sub-{}'.format(sub)),sep = '\t')
    y_test_list[i].to_csv(op.join(file_path, 'neural_funcSTS__ytest_sub-{}'.format(sub)),sep = '\t')

# %%
X_train_list_loaded = []
X_test_list_loaded = []
for sub in sub_labels:
    X_train_list_loaded.append(pd.read_csv(op.join(file_path,'neural_funcSTS_X_train_sub-{}'.format(sub)), sep = '\t', header=None))
    X_test_list_loaded.append(pd.read_csv(op.join(file_path,'neural_funcSTS_X_test_sub-{}'.format(sub)), sep = '\t', header=None))

# %%
counts = y_train_list[0].value_counts().align(y_train_list[1].value_counts())
print(counts)
np.std(np.stack(counts), axis=0)
# Out:
# (Bang           62
# Blij          121
# Boos           97
# Verdrietig     46
# Verrassing     72
# Walging       106
# Name: rating_category, dtype: int64, Bang           48
# Blij          101
# Boos           71
# Verdrietig     38
# Verrassing     46
# Walging        51
# Name: rating_category, dtype: int64)
# array([ 7. , 10. , 13. ,  4. , 13. , 27.5])

# %%
n_test_avg = np.mean([X_test_list[0].shape[0],X_test_list[1].shape[0]])
n_test_avg
# Out:
# 108.0

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.svm import LinearSVC
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score

def auc_validation_calc(X, y, sub, clf, n_runs):
    #init
    ohe = OneHotEncoder(sparse=False)
    auc_score = np.zeros(n_runs)
    names = sorted(y.unique())
    y = y.values[:,np.newaxis]
    y_star = ohe.fit_transform(y)
    auc_dict = {key:[] for key in names}
    
    groups = np.repeat(range(n_runs+1), X.shape[0]/round(n_runs))
    group_kfold = GroupKFold(n_splits=n_runs)

    for train_idx, test_idx in group_kfold.split(X, y, groups):
    #split train set again --> stratified k-fold to optimize trials
        print('loop: %i' %(i))
        clf.fit(X[train_idx], y[train_idx].ravel())
        y_hat = clf.predict(X[test_idx])[:,np.newaxis]
        y_hat_star = ohe.transform(y_hat)
        auc_score[i] = roc_auc_score(y_star[test_idx,:],y_hat_star)
        for i, key in enumerate(names): 
            auc_dict[key].append(roc_auc_score(y_star[test_idx][:,i],y_hat_star[:,i]))
            
    auc_df = pd.DataFrame(data=auc_dict)
    auc_df['overall AUC score'] = auc_score
    mean_score = np.mean(auc_score)
    print('mean AUC score sub-%s: %f' %(sub, mean_score))
    
    return auc_df

# %%
auc_long_list = []
clf = LinearSVC(max_iter=1500)
data = zip(X_train_list, y_train_list, sub_labels)
print('calculating model performance for model with parameters: %s' %(clf.get_params()))
for X, y, sub in data:
    AUC_df = behav.auc_validation_calc(X, y, sub, clf)
    auc_long_list.append(behav.create_long_df(AUC_df))
# Out:
# calculating model performance for model with parameters: {'C': 1.0, 'class_weight': None, 'dual': True, 'fit_intercept': True, 'intercept_scaling': 1, 'loss': 'squared_hinge', 'max_iter': 1500, 'multi_class': 'ovr', 'penalty': 'l2', 'random_state': None, 'tol': 0.0001, 'verbose': 0}
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# mean AUC score sub-04: 0.514960
# mean AUC score sub-13: 0.501663

# %%
auc_long_list = []
clf = LinearSVC(penalty = 'l1', C=10, dual = False, max_iter = 1500, class_weight='balanced')
data = zip(X_train_list, y_train_list, sub_labels)
for X, y, sub in data:
    auc_df = behav.auc_validation_calc(X,y,sub,clf)
    auc_long_list.append(behav.create_long_df(auc_df))
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# mean AUC score sub-04: 0.517135
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# mean AUC score sub-13: 0.511643
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
clf = LinearSVC(penalty = 'l2', C=100, dual = False, max_iter = 1500, class_weight = 'balanced')
auc_long_list = []
data = zip(X_train_list, y_train_list, sub_labels)
for X, y, sub in data:
    auc_df = behav.auc_validation_calc(X,y,sub,clf)
    auc_long_list.append(behav.create_long_df(auc_df))
# Out:
# mean AUC score sub-04: 0.514347
# mean AUC score sub-13: 0.506581

# %%
from sklearn.svm import SVC, LinearSVC

# %%
clf = SVC(kernel = 'linear', class_weight = 'balanced')
auc_long_list = []
data = zip(X_train_list, y_train_list, sub_labels)
for X, y, sub in data:
    auc_df = behav.auc_validation_calc(X,y,sub,clf)
    auc_long_list.append(behav.create_long_df(auc_df))
# Out:
# mean AUC score sub-04: 0.510980
# mean AUC score sub-13: 0.507821

# %%
cvals = [0.1,0.5,1,10,100,1000,10000]
for cval in cvals:
    clf = SVC(kernel = 'linear', class_weight = 'balanced', C=cval)
    auc_long_list = []
    data = zip(X_train_list, y_train_list, sub_labels)
    for X, y, sub in data:
        auc_df = behav.auc_validation_calc(X,y,sub,clf)
        auc_long_list.append(behav.create_long_df(auc_df))
# Out:
# mean AUC score sub-04: 0.509644
# mean AUC score sub-13: 0.507621
# mean AUC score sub-04: 0.508173
# mean AUC score sub-13: 0.507121
# mean AUC score sub-04: 0.511760
# mean AUC score sub-13: 0.511432
# mean AUC score sub-04: 0.514931
# mean AUC score sub-13: 0.511235
# mean AUC score sub-04: 0.511624
# mean AUC score sub-13: 0.506660
# mean AUC score sub-04: 0.512448
# mean AUC score sub-13: 0.507018
# mean AUC score sub-04: 0.509387
# mean AUC score sub-13: 0.511470

# %%
cvals = [0.1,0.5,1,10,100,1000,10000]
for cval in cvals:
    clf = LinearSVC(penalty = 'l2', class_weight = 'balanced', 
                    C=cval, dual = True, max_iter = 2000
                   )
    print('calculating model performance for model with parameters: %s' %(clf.get_params()))
    auc_long_list = []
    data = zip(X_train_list, y_train_list, sub_labels)
    for X, y, sub in data:
        auc_df = behav.auc_validation_calc(X,y,sub,clf)
        auc_long_list.append(behav.create_long_df(auc_df))
# Out:
# calculating model performance for model with parameters: {'C': 0.1, 'class_weight': 'balanced', 'dual': True, 'fit_intercept': True, 'intercept_scaling': 1, 'loss': 'squared_hinge', 'max_iter': 2000, 'multi_class': 'ovr', 'penalty': 'l2', 'random_state': None, 'tol': 0.0001, 'verbose': 0}
# mean AUC score sub-04: 0.516109
# mean AUC score sub-13: 0.505502
# calculating model performance for model with parameters: {'C': 0.5, 'class_weight': 'balanced', 'dual': True, 'fit_intercept': True, 'intercept_scaling': 1, 'loss': 'squared_hinge', 'max_iter': 2000, 'multi_class': 'ovr', 'penalty': 'l2', 'random_state': None, 'tol': 0.0001, 'verbose': 0}
# mean AUC score sub-04: 0.519395
# mean AUC score sub-13: 0.502744
# calculating model performance for model with parameters: {'C': 1, 'class_weight': 'balanced', 'dual': True, 'fit_intercept': True, 'intercept_scaling': 1, 'loss': 'squared_hinge', 'max_iter': 2000, 'multi_class': 'ovr', 'penalty': 'l2', 'random_state': None, 'tol': 0.0001, 'verbose': 0}
# mean AUC score sub-04: 0.517658
# mean AUC score sub-13: 0.501013
# calculating model performance for model with parameters: {'C': 10, 'class_weight': 'balanced', 'dual': True, 'fit_intercept': True, 'intercept_scaling': 1, 'loss': 'squared_hinge', 'max_iter': 2000, 'multi_class': 'ovr', 'penalty': 'l2', 'random_state': None, 'tol': 0.0001, 'verbose': 0}
# mean AUC score sub-04: 0.518965
# mean AUC score sub-13: 0.506894
# calculating model performance for model with parameters: {'C': 100, 'class_weight': 'balanced', 'dual': True, 'fit_intercept': True, 'intercept_scaling': 1, 'loss': 'squared_hinge', 'max_iter': 2000, 'multi_class': 'ovr', 'penalty': 'l2', 'random_state': None, 'tol': 0.0001, 'verbose': 0}
# mean AUC score sub-04: 0.518939
# mean AUC score sub-13: 0.496507
# calculating model performance for model with parameters: {'C': 1000, 'class_weight': 'balanced', 'dual': True, 'fit_intercept': True, 'intercept_scaling': 1, 'loss': 'squared_hinge', 'max_iter': 2000, 'multi_class': 'ovr', 'penalty': 'l2', 'random_state': None, 'tol': 0.0001, 'verbose': 0}
# mean AUC score sub-04: 0.517606
# mean AUC score sub-13: 0.501311
# calculating model performance for model with parameters: {'C': 10000, 'class_weight': 'balanced', 'dual': True, 'fit_intercept': True, 'intercept_scaling': 1, 'loss': 'squared_hinge', 'max_iter': 2000, 'multi_class': 'ovr', 'penalty': 'l2', 'random_state': None, 'tol': 0.0001, 'verbose': 0}
# mean AUC score sub-04: 0.521625
# mean AUC score sub-13: 0.504460

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def plot(auc_dfs, subs):
    n = len(auc_dfs)
    data = zip(auc_dfs, subs)
    fig, ax = plt.subplots(ncols=n, sharey=True, sharex=False, figsize = (15, 15))
    sns.set(palette='husl')
    for i, (df,sub) in enumerate(data):
        if n ==1:
            g = sns.violinplot(x = 'category',y = 'auc_score',data = df, ax=ax)
            for item in g.get_xticklabels():
                item.set_rotation(60)
            ax.set_title('sub-%s:'%(sub))
            ax.plot([-1,7],[0.5,0.5],'k',linewidth = 3.5)
        else:
            g = sns.violinplot(x = 'category',y = 'auc_score',data = df, ax=ax[i])
            for item in g.get_xticklabels():
                item.set_rotation(60)
            ax[i].set_title('sub-%s:'%(sub))
            ax[i].plot([-1,7],[0.5,0.5],'k',linewidth = 3.5)

    plt.show()

# %%
plot(auc_long_list, sub_labels)

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse = False)

# %% [markdown]
# ### Final Cross validation

# %%
data = zip(X_train_list, X_test_list, y_train_list, y_test_list)
#do i need a new ohe? could also return it from function above?
ohe = OneHotEncoder(sparse=False)
auc_long_final = []
auc_df_final = []

clf = LinearSVC(penalty = 'l2', class_weight = 'balanced', 
                    C=10, dual = True, max_iter = 2000
                   )

for X_train, X_test, y_train, y_test in data:
    
    names = sorted(y_train.unique())
    auc_dict = {key:[] for key in names}
    y_train = y_train.values[:,np.newaxis]
    y_test = y_test.values[:,np.newaxis]
    
    ohe.fit_transform(y_train)
    
    y_train_star = ohe.transform(y_train)
    y_test_star = ohe.transform(y_test)
    
    clf.fit(X_train, y_train.ravel())
    y_hat = clf.predict(X_test)
    y_hat_star = ohe.transform(y_hat[:,np.newaxis])
    auc_score = roc_auc_score(y_test_star,y_hat_star)

    for i, key in enumerate(names):
        auc_dict[key].append(roc_auc_score(y_test_star[:,i],y_hat_star[:,i]))

    auc_df_final = pd.DataFrame(data=auc_dict)
    auc_df_final['overall AUC score'] = auc_score
    print(auc_score)
    
    auc_long_final.append(behav.create_long_df(auc_df_final))
# Out:
# 0.5043624373664599
# 0.5348362919271926

# %%
mean_AUC = np.mean([0.5043624373664599,0.5348362919271926])
std_AUC = np.std([0.5043624373664599,0.5348362919271926])
print(mean_AUC, std_AUC)
# Out:
# 0.5195993646468262 0.015236927280366352

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for i, (table, sub) in enumerate(zip(auc_long_final, sub_labels)):
    table['subject'] = sub
    auc_long_final[i] = table
auc_long_final = pd.concat(auc_long_final)
auc_long_final
# Out:
#             category  auc_score subject
# 0               Bang   0.488690      04
# 1               Blij   0.497816      04
# 2               Boos   0.492549      04
# 3         Verdrietig   0.547806      04
# 4         Verrassing   0.509684      04
# 5            Walging   0.489630      04
# 6  overall AUC score   0.504362      04
# 0               Bang   0.489719      13
# 1               Blij   0.556166      13
# 2               Boos   0.547731      13
# 3         Verdrietig   0.622917      13
# 4         Verrassing   0.481352      13
# 5            Walging   0.511134      13
# 6  overall AUC score   0.534836      13

# %%
X_labels = ['Fear', 'Happiness', 'Anger', 'Sadness', 'Surprise', 'Disgust', 'Overal AUC score']

sns.set(palette='dark', style='white', font_scale=1.5)
g = sns.catplot(x = 'category',y = 'auc_score', 
                hue = 'subject', kind = 'bar', 
                data = auc_long_final, aspect = 2.3,
               )
g.despine(left = True)

for item in g.ax.get_xticklabels():
    item.set_rotation(50)
g.ax.set_title('Static-dynamic functional ROI')
g.ax.set_ylabel('AUROC score')
g.ax.set_xlabel('Emotion category')
g.ax.set_xticklabels(X_labels)
g.ax.plot([-1,7],[0.5,0.5],'k',linewidth = 3.5)
g.ax.plot([3.2],[0.64],'*', c = 'k', ms = 6)
g.ax.set_ylim((0.4,0.9))

plt.show()

# %% [markdown]
# ### Permutation tests

# %%
clf = LinearSVC(penalty = 'l2', class_weight = 'balanced', 
                    C=10, dual = True, max_iter = 2000
                   )
n_perm = 1000
auc_scores_all = []
data = zip(X_train_list, X_test_list,y_train_list, y_test_list)

for X_train, X_test, y_train, y_test in data:
    names = sorted(y_train.unique())
    y_train = y_train.values[:,np.newaxis]
    y_train_star = ohe.fit_transform(y_train)
    y_test = y_test.values[:,np.newaxis]
    y_test_star = ohe.transform(y_test)
    auc_scores = np.zeros((n_perm,7))
    
    for perm in range(n_perm):
        if isinstance(perm/50, int):
            print('permutation ', perm)
        np.random.shuffle(X_train)
        auc_dict = {key:[] for key in names}
        clf.fit(X_train, y_train.ravel())
        y_hat_star = ohe.transform(clf.predict(X_test)[:,np.newaxis])
        auc_score = roc_auc_score(y_test_star,y_hat_star)
        for i, key in enumerate(names):
            auc_dict[key].append(roc_auc_score(y_test_star[:,i],y_hat_star[:,i]))

        auc_df = pd.DataFrame(data=auc_dict)
        auc_df['overall AUC score'] = auc_score
        auc_scores[perm,:] = auc_df.values
    auc_scores_all.append(auc_scores)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
auc_df_04 = auc_long_final[auc_long_final.subject == '04']
auc_df_13 = auc_long_final[auc_long_final.subject == '13']
auc_lists = [auc_df_04, auc_df_13]

# %%
for permscores, auc_list in zip(auc_scores_all,auc_lists):
    fig, ax = plt.subplots(nrows=7,ncols=1, figsize = (10,30))
    for i, cat in enumerate(permscores.T):
        ax[i].hist(cat, bins = 75)
        ax[i].set_title('sub: %s, cat: %s' %(auc_list.loc[i,'subject'],auc_df.columns[i]))
        ax[i].plot([auc_list.loc[i,'auc_score'], auc_list.loc[i,'auc_score']], [0,75],'k',linewidth = 5)

# %%
for permscores, auc_list in zip(auc_scores_all,auc_lists):
    for i, cat in enumerate(permscores.T):
        pval = (np.sum(auc_list.loc[i, 'auc_score'] <= cat ) +1)/(cat.shape[0]+1)
        print('permuted P-val for subject %s, category: %s = %.3f' %(auc_list.loc[i,'subject'],auc_df.columns[i],pval))
# Out:
# permuted P-val for subject 04, category: Bang = 0.601
# permuted P-val for subject 04, category: Blij = 0.529
# permuted P-val for subject 04, category: Boos = 0.521
# permuted P-val for subject 04, category: Verdrietig = 0.181
# permuted P-val for subject 04, category: Verrassing = 0.412
# permuted P-val for subject 04, category: Walging = 0.572
# permuted P-val for subject 04, category: overall AUC score = 0.407
# permuted P-val for subject 13, category: Bang = 0.576
# permuted P-val for subject 13, category: Blij = 0.149
# permuted P-val for subject 13, category: Boos = 0.177
# permuted P-val for subject 13, category: Verdrietig = 0.044
# permuted P-val for subject 13, category: Verrassing = 0.674
# permuted P-val for subject 13, category: Walging = 0.405
# permuted P-val for subject 13, category: overall AUC score = 0.092

# %% [markdown]
# lisa Feltmann barrett voor papers emotion --> constructed identities
# - context hier weggestript (nodig voor AU analyse maar niet natuurgetrouw?)
# - wij vinden niet direct terug dat er representatie is van AU in het brein (in naturalistic pradigm) tov van
# -
